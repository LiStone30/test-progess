# %% [markdown]
# # Cell Progress test
#
# Run the untracked cell first, then run the tracked cell.

# %%
print("This cell is intentionally not tracked.")

# %%
print("Tracked Cell Progress test completed.")
